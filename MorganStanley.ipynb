# %%
library(rcompanion)
library(readxl)
library(ggplot2)
library(IntroCompFinR)
library(methods)
library(dplyr)
library(lubridate)
library(corrplot)

# %%
MorganStanley = read.csv(r"(C:\Users\Mary\Documents\Data Science Classes\Final Project\Week 2\MS.csv)")

MorganStanley
# Out:
#      Date       Open     High     Low      Close    Adj.Close Volume
# 1    1999-01-04 35.40625 37.46875 35.40625 36.37500 19.25095   6026800
# 2    1999-01-05 36.37500 37.62500 36.37500 37.50000 19.84634   4945600
# 3    1999-01-06 39.00000 40.75000 38.78125 40.34375 21.35136   7970600
# 4    1999-01-07 41.50000 42.81250 41.06250 42.09375 22.27753   7938400
# 5    1999-01-08 42.56250 44.25000 42.25000 44.12500 23.35253   7811800
# 6    1999-01-11 43.50000 44.40625 42.87500 43.75000 23.15408   4614800
# 7    1999-01-12 42.75000 42.93750 40.84375 41.21875 21.81444   6436400
# 8    1999-01-13 38.00000 41.75000 37.90625 41.15625 21.78137   9383800
# 9    1999-01-14 41.03125 41.71875 40.12500 40.40625 21.44697   4963800
# 10   1999-01-15 41.65625 42.78125 41.25000 42.78125 22.70757   4883200
# 11   1999-01-19 44.43750 44.43750 42.00000 42.43750 22.52511   4489400
# 12   1999-01-20 43.25000 44.25000 42.81250 43.75000 23.22178   4400800
# ...

# %%
# What is the average per day?

MorganStanley$rowMeans = rowMeans(MorganStanley[ , c(2,3,4,5)], na.rm=TRUE)

MorganStanley$rowMeans
# Out:
#    [1]  36.16406  36.96875  39.71875  41.86719  43.29688  43.63281  41.93750
#    [8]  39.70312  40.82031  42.11719  43.32812  43.51562  42.82031  41.35156
#   [15]  41.35156  41.72656  41.69531  41.44531  43.23438  43.70312  43.96875
#   [22]  45.27344  45.50781  44.26562  44.32031  43.73438  42.57031  44.37500
#   [29]  44.85938  44.89844  44.60156  45.19531  46.64062  47.50000  48.11719
#   [36]  46.50000  44.78125  45.11719  45.21094  45.34375  45.91406  47.72656
#   [43]  49.33594  49.17969  48.88281  49.35938  50.42969  50.90625  50.74219
#   [50]  51.35938  50.30469  50.71875  51.29688  49.12500  48.66406  48.96875
#   [57]  51.52344  51.45312  52.41406  51.54688  50.44531  49.80469  51.00000
#   [64]  52.31250  53.52344  54.36719  54.89844  55.57031  57.25781  56.28125
#   [71]  53.59375  52.50781  50.94531  48.90625  50.35156  52.00000  52.24219
#   [78]  51.59375  51.68750  51.81250  51.75781  50.80469  50.46875  50.96875
# ...

# %%
#MorganStanley$Date <- gsub('/', '-', MorganStanley$Date)
#MorganStanley

# %%
### Do not use.
#MorganStanley$Date = as.Date(MorganStanley$Date, format= "%m-%d-%Y")

# %%
### Do not use. Experimenting with this code
#MorganStanley$DateR = as.Date(MorganStanley$Date, format= "%m-%d-%Y")

# %%
MorganStanley$Day <- lubridate::day(MorganStanley$Date)
MorganStanley$Month <- lubridate::month(MorganStanley$Date)
MorganStanley$Year <- lubridate::year(MorganStanley$Date)

# %%
MorganStanley
# Out:
#      Date       Open     High     Low      Close    Adj.Close Volume   rowMeans
# 1    1999-01-04 35.40625 37.46875 35.40625 36.37500 19.25095   6026800 36.16406
# 2    1999-01-05 36.37500 37.62500 36.37500 37.50000 19.84634   4945600 36.96875
# 3    1999-01-06 39.00000 40.75000 38.78125 40.34375 21.35136   7970600 39.71875
# 4    1999-01-07 41.50000 42.81250 41.06250 42.09375 22.27753   7938400 41.86719
# 5    1999-01-08 42.56250 44.25000 42.25000 44.12500 23.35253   7811800 43.29688
# 6    1999-01-11 43.50000 44.40625 42.87500 43.75000 23.15408   4614800 43.63281
# 7    1999-01-12 42.75000 42.93750 40.84375 41.21875 21.81444   6436400 41.93750
# 8    1999-01-13 38.00000 41.75000 37.90625 41.15625 21.78137   9383800 39.70312
# 9    1999-01-14 41.03125 41.71875 40.12500 40.40625 21.44697   4963800 40.82031
# 10   1999-01-15 41.65625 42.78125 41.25000 42.78125 22.70757   4883200 42.11719
# 11   1999-01-19 44.43750 44.43750 42.00000 42.43750 22.52511   4489400 43.32812
# ...

# %%
options(repr.plot.width=15, repr.plot.height=8)

ggplot(MorganStanley, aes(x=Date, y=rowMeans, group = Day)) +
  geom_line(color="#69b3a2") +
  ggtitle("Average Price per Day") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=1))
# Out:
# plot without title

# %%
options(repr.plot.width=15, repr.plot.height=8)

ggplot(MorganStanley, aes(x=Year, y=rowMeans, group = Month)) +
  geom_line(color="red") +
  ggtitle("Average Price per Month") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=2))
# Out:
# plot without title

# %%
options(repr.plot.width=15, repr.plot.height=8)

ggplot(MorganStanley, aes(x=Year, y=rowMeans, group = Month)) +
  geom_line(aes(color=Month)) +
  ggtitle("Average Price per Year By Month") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=2)) +
  theme(plot.title = element_text(size = 40, face = "bold", color="darkblue", hjust=0.5))
# Out:
# plot without title

# %%
options(repr.plot.width=15, repr.plot.height=8)

ggplot(MorganStanley, aes(x=Date, y=rowMeans, group = Year)) +
  geom_line(color="sky blue") +
  ggtitle("Average Price per Year") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=1))
# Out:
# plot without title

# %%
# What is the difference between high low prices in 1999 to 2022?

range(MorganStanley$Open)
# Out:
# [1]   9.1900 108.4375

# %%
range(MorganStanley$High)
# Out:
# [1]  10.21 110.00

# %%
range(MorganStanley$Low)
# Out:
# [1]   6.710 106.375

# %%
range(MorganStanley$Close)
# Out:
# [1]   9.200 109.375

# %%
range(MorganStanley$Adj.Close)
# Out:
# [1]   7.001352 100.356041

# %%
# Difference between High and Low Price by row from 1999 to 2022

highLowDiff = MorganStanley[, 3] - MorganStanley[, 4]

MorganStanley$highLowDiff = highLowDiff

MorganStanley$highLowDiff
# Out:
#    [1]  2.062500  1.250000  1.968750  1.750000  2.000000  1.531250  2.093750
#    [8]  3.843750  1.593750  1.531250  2.437500  1.437500  1.062500  1.687500
#   [15]  0.968750  1.000000  1.781250  1.750000  1.625000  1.406250  1.875000
#   [22]  3.781250  1.468750  2.000000  1.187500  2.062500  1.187500  3.375000
#   [29]  1.937500  1.000000  2.093750  2.812500  2.500000  2.125000  1.250000
#   [36]  3.656250  1.781250  1.312500  1.593750  1.093750  1.375000  1.593750
#   [43]  1.281250  1.437500  2.218750  0.812500  1.468750  1.312500  1.468750
#   [50]  1.437500  1.406250  1.937500  2.406250  1.937500  1.093750  1.750000
#   [57]  1.656250  0.812500  1.218750  1.375000  1.343750  0.750000  1.343750
#   [64]  1.968750  2.312500  1.437500  2.406250  1.468750  1.875000  3.906250
#   [71]  2.625000  1.906250  6.218750  1.937500  2.593750  0.937500  1.406250
#   [78]  2.812500  2.093750  1.718750  1.156250  3.812500  4.406250  4.281250
# ...

# %%
options(repr.plot.width=15, repr.plot.height=8)

ggplot(MorganStanley, aes(x=Date, y=highLowDiff, group = Year)) +
  geom_line(color="green") +
  ggtitle("Difference between High & Low Price per Year") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=1))
# Out:
# plot without title

# %%
# Have the prices gotten higher or lower from 1999-2022?

options(repr.plot.width=15, repr.plot.height=8)

ggplot(MorganStanley, aes(x=Date, y=Open, group = Year)) +
  geom_line(aes(color=Year)) +
  ggtitle("Have the Prices gotten Higher or Lower from 1999 to 2022") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=2)) +
  theme(plot.title = element_text(size = 30, face = "bold", color="dark blue", hjust=0.5))
# Out:
# plot without title

# %%
# What Months are the best months of Trading within 1999-2022

# %%
# Difference between Open & Closing Prices

OpenCloseDiff = MorganStanley[, 2] - MorganStanley[, 5]

MorganStanley$OpenCloseDiff = OpenCloseDiff

MorganStanley$OpenCloseDiff
# Out:
#    [1]  -0.968750  -1.125000  -1.343750  -0.593750  -1.562500  -0.250000
#    [7]   1.531250  -3.156250   0.625000  -1.125000   2.000000  -0.500000
#   [13]  -0.031250   1.406250   0.000000  -0.906250   1.562500  -1.156250
#   [19]  -0.312500  -0.656250  -1.000000  -1.875000   1.312500   0.312500
#   [25]   0.156250   1.375000   0.156250  -3.375000   1.250000  -0.281250
#   [31]   0.375000  -1.968750  -0.187500  -2.000000  -0.031250   3.218750
#   [37]   0.093750  -0.406250   0.062500   0.156250  -1.093750  -1.000000
#   [43]   0.250000   0.781250  -1.125000  -0.125000  -0.875000   0.625000
#   [49]  -0.500000   0.750000   1.250000  -1.937500   1.156250   1.812500
#   [55]  -0.375000   0.250000  -0.312500   0.062500  -0.687500   1.312500
#   [61]   0.937500  -0.093750  -1.031250  -0.531250  -1.781250   1.031250
#   [67]  -1.500000  -0.937500  -0.218750   2.843750   2.375000   0.500000
#   [73]   6.000000  -1.437500  -1.437500  -0.312500  -0.312500   2.812500
# ...

# %%
options(repr.plot.width=15, repr.plot.height=8)

ggplot(MorganStanley, aes(x=Date, y=OpenCloseDiff, group = Day)) +
  geom_line(aes(color=Month)) +
  ggtitle("Difference between Open & Close Prices By Month") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=2)) +
  theme(plot.title = element_text(size = 30, face = "bold", color="dark blue", hjust=0.5))
# Out:
# plot without title

# %%
# Is there a Significance between Adjusted Close Price & Close Price?

options(repr.plot.width=15, repr.plot.height=8)

ggplot(MorganStanley, aes(x=Close, y=Adj.Close, group = Year)) +
  geom_line(color="orange") +
  ggtitle("Significance between Close & Adjusted Close Price per Year") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=1))
# Out:
# plot without title

# %%
# Does the # of Shares Bought (Volume) affect the Closing Price?

options(repr.plot.width=15, repr.plot.height=8)

ggplot(MorganStanley, aes(x=Close, y=Volume, group = Year)) +
  geom_line(color="orange") +
  ggtitle("Volume bought per Closing Price per Year") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=1))
# Out:
# plot without title

# %%
# It looks like initially the volume bough affected the closing price, however, upon research volume does not affect the closing price.

# %%
# Which stocks correlate with each other?

cor(MorganStanley[,c("Open","High","Low","Close","Adj.Close","Volume")])
# Out:
#           Open       High       Low        Close      Adj.Close  Volume
# Open       1.0000000  0.9992586  0.9991591  0.9985681  0.8529682 -0.4540316
# High       0.9992586  1.0000000  0.9987340  0.9992924  0.8500034 -0.4452925
# Low        0.9991591  0.9987340  1.0000000  0.9992278  0.8568682 -0.4649798
# Close      0.9985681  0.9992924  0.9992278  1.0000000  0.8537388 -0.4534550
# Adj.Close  0.8529682  0.8500034  0.8568682  0.8537388  1.0000000 -0.2981441
# Volume    -0.4540316 -0.4452925 -0.4649798 -0.4534550 -0.2981441  1.0000000

# %%
corrplot(cor(MorganStanley[,c("Open","High","Low","Close","Adj.Close","Volume")]),
  method = "number",
  type = "upper" # show only upper side
)
# Out:
# Plot with title ""
