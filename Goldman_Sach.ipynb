# %%
library(rcompanion)
library(readxl)
library(ggplot2)
library(IntroCompFinR)
library(methods)
library(dplyr)
library(lubridate)

# %%
#     https://www.kaggle.com/datasets/varpit94/goldman-sachs-stock-data-updated-till-1jul2021

# %%
GoldmanSachs = read.csv(r"(C:\Users\Mary\Documents\Data Science Classes\Final Project\GS.csv)")

GoldmanSachs
# Out:
#      Date       Open    High    Low     Close   Adj.Close Volume
# 1    1999-05-04 76.0000 77.2500 70.0000 70.3750 53.57680  22320900
# 2    1999-05-05 69.8750 69.8750 66.2500 69.1250 52.62515   7565700
# 3    1999-05-06 68.0000 69.3750 67.0625 67.9375 51.72110   2905700
# 4    1999-05-07 67.9375 74.8750 66.7500 74.1250 56.43165   4862300
# 5    1999-05-10 73.3750 73.5000 70.2500 70.6875 53.81471   2589400
# 6    1999-05-11 70.0000 71.1875 69.5000 70.6250 53.76712   1839800
# 7    1999-05-12 71.0000 74.8750 69.1250 73.5000 55.95587   2659300
# 8    1999-05-13 73.2500 75.2500 72.5000 73.1875 55.71795   1142900
# 9    1999-05-14 71.2500 72.2500 69.0625 70.1875 53.43403   2058400
# 10   1999-05-17 69.1250 70.2500 68.0000 68.6250 52.24450   2075000
# 11   1999-05-18 68.2500 70.4375 68.1250 68.6250 52.24450   1407100
# 12   1999-05-19 69.3750 69.8125 68.7500 69.3125 52.76792    727400
# 13   1999-05-20 69.5625 70.1250 68.3750 68.3750 52.05420    520800
# ...

# %%
# What is the average per day?

GoldmanSachs$rowMeans = rowMeans(GoldmanSachs[ , c(2,3,4,5)], na.rm=TRUE)

GoldmanSachs$rowMeans
# Out:
#    [1]  73.40625  68.78125  68.09375  70.92188  71.95312  70.32812  72.12500
#    [8]  73.54688  70.68750  69.00000  68.85938  69.31250  69.10938  67.98438
#   [15]  66.14062  64.64062  65.34375  66.29688  67.87500  65.25000  63.26562
#   [22]  63.73438  65.25000  66.01562  64.64062  64.71875  64.12500  63.45312
#   [29]  62.31250  62.81250  64.64062  65.21875  64.35938  68.17188  69.00000
#   [36]  66.09375  65.53125  65.98438  66.56250  67.06250  69.78125  70.84375
#   [43]  70.59375  70.23438  68.89062  67.82812  67.53125  68.29688  68.10938
#   [50]  67.51562  67.85938  68.07812  69.17188  68.89062  67.76562  67.34375
#   [57]  65.20312  63.85938  64.70312  65.42188  65.12500  64.48438  63.50000
#   [64]  61.79688  60.51562  59.21875  57.53125  56.40625  56.40625  59.59375
#   [71]  61.21875  62.71875  62.43750  63.34375  62.34375  61.62500  62.17188
#   [78]  63.21875  63.70312  63.43750  63.59375  62.26562  60.53125  59.62500
# ...

# %%
GoldmanSachs$Day <- lubridate::day(GoldmanSachs$Date)

# %%
options(repr.plot.width=15, repr.plot.height=8)

ggplot(GoldmanSachs, aes(x=Date, y=rowMeans, group = Day)) +
  geom_line(color="#69b3a2") +
  ggtitle("Average Price per Day") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=1))
# Out:
# plot without title

# %%
GoldmanSachs$Month <- lubridate::month(GoldmanSachs$Date)

# %%
options(repr.plot.width=15, repr.plot.height=8)

ggplot(GoldmanSachs, aes(x=Year, y=rowMeans, group = Month)) +
  geom_line(color="red") +
  ggtitle("Average Price per Month") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=2))
# Out:
# plot without title

# %%
options(repr.plot.width=15, repr.plot.height=8)

ggplot(GoldmanSachs, aes(x=Year, y=rowMeans, group = Month)) +
  geom_line(aes(color=Month)) +
  ggtitle("Average Price per Year By Month") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=2)) +
  theme(plot.title = element_text(size = 40, face = "bold", color="darkblue", hjust=0.5))
# Out:
# plot without title

# %%
GoldmanSachs$Year <- lubridate::year(GoldmanSachs$Date)

# %%
options(repr.plot.width=15, repr.plot.height=8)

ggplot(GoldmanSachs, aes(x=Date, y=rowMeans, group = Year)) +
  geom_line(color="sky blue") +
  ggtitle("Average Price per Year") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=1))
# Out:
# plot without title

# %%
unique(GoldmanSachs$Year)
# Out:
#  [1] 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013
# [16] 2014 2015 2016 2017 2018 2019 2020 2021 2022

# %%
# What is the difference between high low prices in 1999 to 2022?

range(GoldmanSachs$Open)
# Out:
# [1]  54.00 423.12

# %%
range(GoldmanSachs$High)
# Out:
# [1]  54.54 426.16

# %%
range(GoldmanSachs$Low)
# Out:
# [1]  47.41 413.76

# %%
range(GoldmanSachs$Close)
# Out:
# [1]  52.00 423.85

# %%
range(GoldmanSachs$Adj.Close)
# Out:
# [1]  42.4903 419.1542

# %%
# Difference between High and Low Price by row from 1999 to 2022

highLowDiff = GoldmanSachs[, 3] - GoldmanSachs[, 4]

GoldmanSachs$highLowDiff = highLowDiff

GoldmanSachs$highLowDiff
# Out:
#    [1]  7.250000  3.625000  2.312500  8.125000  3.250000  1.687500  5.750000
#    [8]  2.750000  3.187500  2.250000  2.312500  1.062500  1.750000  1.312500
#   [15]  2.250000  1.937500  3.562500  3.062500  1.812500  3.062500  2.062500
#   [22]  1.062500  2.687500  2.562500  1.937500  1.875000  1.625000  2.000000
#   [29]  3.500000  1.125000  1.500000  2.375000  1.375000  3.375000  2.375000
#   [36]  2.562500  2.000000  1.437500  1.750000  2.500000  6.125000  1.687500
#   [43]  1.500000  1.937500  2.000000  1.687500  0.937500  1.062500  1.062500
#   [50]  0.437500  0.500000  1.000000  2.500000  2.562500  0.937500  1.750000
#   [57]  2.375000  1.562500  2.437500  2.375000  1.000000  1.375000  2.187500
#   [64]  2.062500  1.500000  2.187500  2.937500  1.687500  2.000000  4.125000
#   [71]  1.625000  1.187500  2.125000  1.875000  1.937500  1.687500  1.312500
#   [78]  1.187500  2.187500  2.000000  2.125000  1.500000  2.437500  1.812500
# ...

# %%
GoldmanSachs
# Out:
#      Date       Open    High    Low     Close   Adj.Close Volume   rowMeans Day
# 1    1999-05-04 76.0000 77.2500 70.0000 70.3750 53.57680  22320900 73.40625  4
# 2    1999-05-05 69.8750 69.8750 66.2500 69.1250 52.62515   7565700 68.78125  5
# 3    1999-05-06 68.0000 69.3750 67.0625 67.9375 51.72110   2905700 68.09375  6
# 4    1999-05-07 67.9375 74.8750 66.7500 74.1250 56.43165   4862300 70.92188  7
# 5    1999-05-10 73.3750 73.5000 70.2500 70.6875 53.81471   2589400 71.95312 10
# 6    1999-05-11 70.0000 71.1875 69.5000 70.6250 53.76712   1839800 70.32812 11
# 7    1999-05-12 71.0000 74.8750 69.1250 73.5000 55.95587   2659300 72.12500 12
# 8    1999-05-13 73.2500 75.2500 72.5000 73.1875 55.71795   1142900 73.54688 13
# 9    1999-05-14 71.2500 72.2500 69.0625 70.1875 53.43403   2058400 70.68750 14
# 10   1999-05-17 69.1250 70.2500 68.0000 68.6250 52.24450   2075000 69.00000 17
# 11   1999-05-18 68.2500 70.4375 68.1250 68.6250 52.24450   1407100 68.85938 18
# ...

# %%
options(repr.plot.width=15, repr.plot.height=8)

ggplot(GoldmanSachs, aes(x=Date, y=highLowDiff, group = Year)) +
  geom_line(color="green") +
  ggtitle("Difference between High & Low Price per Year") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=1))
# Out:
# plot without title

# %%
# What is the Difference between Adjusted Closing Price and Regular Closing Price

ClosingDiff = GoldmanSachs[, 5] - GoldmanSachs[, 6]

GoldmanSachs$ClosingDiff = ClosingDiff

GoldmanSachs$ClosingDiff
# Out:
#    [1] 16.798203 16.499847 16.216400 17.693352 16.872791 16.857883 17.544128
#    [8] 17.469555 16.753471 16.380501 16.380501 16.544575 16.320801 16.111969
#   [15] 15.589817 15.395863 15.768833 16.171642 16.216400 15.321285 15.097500
#   [22] 15.187016 15.604752 15.739002 15.216862 15.634583 15.127327 15.097500
#   [29] 14.620113 14.978153 15.574890 15.515236 15.470482 16.589348 16.231319
#   [36] 15.515236 15.530163 15.813602 15.888195 16.171642 17.245766 16.902630
#   [43] 16.932484 16.828041 16.231319 16.052288 16.052288 16.320801 16.201477
#   [50] 16.141811 16.216400 16.246223 16.574432 16.261143 16.201477 15.873276
#   [57] 15.291447 15.097500 15.634583 15.768833 15.515236 15.351109 14.993095
#   [64] 14.515675 14.321743 14.142727 13.426624 13.322205 13.512150 14.578930
#   [71] 14.386284 14.964123 14.904850 14.934502 14.771515 14.593731 14.771515
#   [78] 15.082649 15.038200 15.171528 14.875214 14.593731 14.060349 14.178886
# ...

# %%
GoldmanSachs
# Out:
#      Date       Open    High    Low     Close   Adj.Close Volume   highLowDiff
# 1    1999-05-04 76.0000 77.2500 70.0000 70.3750 53.57680  22320900 7.2500
# 2    1999-05-05 69.8750 69.8750 66.2500 69.1250 52.62515   7565700 3.6250
# 3    1999-05-06 68.0000 69.3750 67.0625 67.9375 51.72110   2905700 2.3125
# 4    1999-05-07 67.9375 74.8750 66.7500 74.1250 56.43165   4862300 8.1250
# 5    1999-05-10 73.3750 73.5000 70.2500 70.6875 53.81471   2589400 3.2500
# 6    1999-05-11 70.0000 71.1875 69.5000 70.6250 53.76712   1839800 1.6875
# 7    1999-05-12 71.0000 74.8750 69.1250 73.5000 55.95587   2659300 5.7500
# 8    1999-05-13 73.2500 75.2500 72.5000 73.1875 55.71795   1142900 2.7500
# 9    1999-05-14 71.2500 72.2500 69.0625 70.1875 53.43403   2058400 3.1875
# 10   1999-05-17 69.1250 70.2500 68.0000 68.6250 52.24450   2075000 2.2500
# 11   1999-05-18 68.2500 70.4375 68.1250 68.6250 52.24450   1407100 2.3125
# 12   1999-05-19 69.3750 69.8125 68.7500 69.3125 52.76792    727400 1.0625
# ...

# %%
options(repr.plot.width=15, repr.plot.height=8)

ggplot(GoldmanSachs, aes(x=Date, y=ClosingDiff, group = Year)) +
  geom_line(color="gold") +
  ggtitle("Difference between Adjusted Close & Close per Year") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=1))
# Out:
# plot without title

# %%
options(repr.plot.width=15, repr.plot.height=8)

ggplot(GoldmanSachs, aes(x=Year, y=ClosingDiff, group = Month)) +
  geom_line(aes(color=Month)) +
  ggtitle("Difference between Adjusted Close & Close per Year By Month") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=2)) +
  theme(plot.title = element_text(size = 30, face = "bold", color="dark blue", hjust=0.5))
# Out:
# plot without title

# %%
# Have the prices gotten higher or lower from 1999-2022?

options(repr.plot.width=15, repr.plot.height=8)

ggplot(GoldmanSachs, aes(x=Date, y=Open, group = Year)) +
  geom_line(aes(color=Year)) +
  ggtitle("Have the Prices gotten Higher or Lower from 1999 to 2022") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=2)) +
  theme(plot.title = element_text(size = 30, face = "bold", color="dark blue", hjust=0.5))
# Out:
# plot without title

# %%
options(repr.plot.width=15, repr.plot.height=8)

ggplot(GoldmanSachs, aes(x=Date, y=Close, group = Year)) +
  geom_line(aes(color=Year)) +
  ggtitle("Have the Prices gotten Higher or Lower from 1999 to 2022") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=2)) +
  theme(plot.title = element_text(size = 30, face = "bold", color="dark blue", hjust=0.5))
# Out:
# plot without title

# %%
# What Months are the best Months of Trading within 1999-2022

# %%
# Difference between Open & Closing Prices

OpenCloseDiff = GoldmanSachs[, 2] - GoldmanSachs[, 5]

GoldmanSachs$OpenCloseDiff = OpenCloseDiff

GoldmanSachs$OpenCloseDiff
# Out:
#    [1]   5.625000   0.750000   0.062500  -6.187500   2.687500  -0.625000
#    [7]  -2.500000   0.062500   1.062500   0.500000  -0.375000   0.062500
#   [13]   1.187500   0.625000   1.687500  -0.375000  -0.437500  -2.750000
#   [19]  -0.187500   2.437500   0.500000   0.375000  -1.062500  -0.750000
#   [25]   1.625000  -1.250000   1.500000   0.687500   2.250000   0.125000
#   [31]  -1.312500  -0.500000  -0.562500  -2.812500   2.125000   2.062500
#   [37]   1.000000  -0.750000  -0.125000  -1.750000  -3.750000   0.562500
#   [43]  -0.375000  -0.500000   1.562500   0.750000   0.187500  -0.375000
#   [49]   0.375000  -0.250000   0.062500  -0.312500  -1.187500   1.000000
#   [55]   0.125000   1.625000   2.312500   1.000000  -1.250000  -0.812500
#   [61]   0.500000   0.687500   1.437500   2.000000   0.562500   0.562500
#   [67]   2.687500   0.687500  -0.750000  -3.625000   0.750000  -0.687500
#   [73]   0.125000   0.250000   0.687500   0.062500  -0.500000  -0.812500
# ...

# %%
options(repr.plot.width=15, repr.plot.height=8)

ggplot(GoldmanSachs, aes(x=Date, y=OpenCloseDiff, group = Day)) +
  geom_line(aes(color=Month)) +
  ggtitle("Difference between Open & Close Prices By Month") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=2)) +
  theme(plot.title = element_text(size = 30, face = "bold", color="dark blue", hjust=0.5))
# Out:
# plot without title

# %%
options(repr.plot.width=15, repr.plot.height=8)

ggplot(GoldmanSachs, aes(x=Date, y=OpenCloseDiff, group = Year)) +
  geom_line(color="pink") +
  ggtitle("Difference between Open & Close Price per Year") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=1))
# Out:
# plot without title

# %%
# Is there a Significance between Adjusted Close Price & Close Price?

options(repr.plot.width=15, repr.plot.height=8)

ggplot(GoldmanSachs, aes(x=Close, y=Volume, group = Year)) +
  geom_line(color="orange") +
  ggtitle("Volume bought per Closing Price per Year") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=1))

# %%
# Does the # of Shares Bought (Volume) affect the Closing Price?

options(repr.plot.width=15, repr.plot.height=8)

ggplot(GoldmanSachs, aes(x=Close, y=Volume, group = Year)) +
  geom_line(color="orange") +
  ggtitle("Volume bought per Closing Price per Year") +
  theme(axis.text.x = element_text(angle = 90, vjust = 1, hjust=1))
# Out:
# plot without title

# %%
# It looks like initially the volume bough affected the closing price, however, upon research volume does not affect the closing price.
